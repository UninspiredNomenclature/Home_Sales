# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java

# !pip install pyspark

# !apt-get update
# !apt-get install ...
# !wget -q ...
# !tar xf ...
# !pip install -q findspark
# !pip install py4j
# Out:
# Streaming output truncated to the last 5000 lines.
#                                 Conflicts: libcuda-12.2-1
#                                 Conflicts: libcuda-12.3-1
#                                 Conflicts: libcuda-12.4-1
#                                 Conflicts: libcuda-5.0-1
#                                 Conflicts: libcuda-5.5-1
#                                 Conflicts: libcuda-6.0-1
#                                 Conflicts: libcuda-6.5-1
#                                 Conflicts: libcuda-7.0-1
#                                 Conflicts: libcuda-7.5-1
#                                 Conflicts: libcuda-8.0-1
#                                 Conflicts: libcuda-9.0-1
#                                 Conflicts: libcuda-9.1-1
#                                 Conflicts: libcuda-9.2-1
#                                 Conflicts: libnvidia-compute
#                                 Conflicts: nvidia-opencl-icd
#  libnvidia-decode-390 : Conflicts: libnvidia-decode
#  libnvidia-decode-418-server : Conflicts: libnvidia-decode
#  libnvidia-decode-450-server : Conflicts: libnvidia-decode
#  libnvidia-decode-470 : Conflicts: libnvidia-decode
#  libnvidia-decode-470-server : Conflicts: libnvidia-decode
#  libnvidia-decode-515 : Conflicts: libnvidia-decode
#  libnvidia-decode-520 : Conflicts: libnvidia-decode
#  libnvidia-decode-525 : Conflicts: libnvidia-decode
#  libnvidia-decode-535 : Conflicts: libnvidia-decode
#  libnvidia-decode-535-server : Conflicts: libnvidia-decode
#  libnvidia-decode-545 : Conflicts: libnvidia-decode
#  libnvidia-decode-550 : Conflicts: libnvidia-decode
#  libnvidia-decode-550-server : Conflicts: libnvidia-decode
#  libnvidia-decode-555 : Conflicts: libnvidia-decode
#  libnvidia-decode-560 : Conflicts: libnvidia-decode
#  libnvidia-decode-565 : Conflicts: libnvidia-decode
#  libnvidia-decode-565-server : Conflicts: libnvidia-decode
#  libnvidia-egl-wayland1 : Conflicts: libnvidia-gl-390 but 390.157-0ubuntu0.22.04.2 is to be installed
#  libnvidia-encode-390 : Conflicts: libnvidia-encode
#  libnvidia-encode-418-server : Conflicts: libnvidia-encode
#  libnvidia-encode-450-server : Conflicts: libnvidia-encode
#  libnvidia-encode-470 : Conflicts: libnvidia-encode
#  libnvidia-encode-470-server : Conflicts: libnvidia-encode
#  libnvidia-encode-515 : Conflicts: libnvidia-encode
#  libnvidia-encode-520 : Conflicts: libnvidia-encode
#  libnvidia-encode-525 : Conflicts: libnvidia-encode
#  libnvidia-encode-535 : Conflicts: libnvidia-encode
#  libnvidia-encode-535-server : Conflicts: libnvidia-encode
#  libnvidia-encode-545 : Conflicts: libnvidia-encode
#  libnvidia-encode-550 : Conflicts: libnvidia-encode
#  libnvidia-encode-550-server : Conflicts: libnvidia-encode
#  libnvidia-encode-555 : Conflicts: libnvidia-encode
#  libnvidia-encode-560 : Conflicts: libnvidia-encode
#  libnvidia-encode-565 : Conflicts: libnvidia-encode
#  libnvidia-encode-565-server : Conflicts: libnvidia-encode
#  libnvidia-extra-450-server : Conflicts: libnvidia-extra
#  libnvidia-extra-470 : Conflicts: libnvidia-extra
#  libnvidia-extra-470-server : Conflicts: libnvidia-extra
#  libnvidia-extra-515 : Conflicts: libnvidia-extra
#  libnvidia-extra-520 : Conflicts: libnvidia-extra
#  libnvidia-extra-525 : Conflicts: libnvidia-extra
#  libnvidia-extra-535 : Conflicts: libnvidia-extra
#  libnvidia-extra-535-server : Conflicts: libnvidia-extra
#  libnvidia-extra-545 : Conflicts: libnvidia-extra
#  libnvidia-extra-550 : Conflicts: libnvidia-extra
#  libnvidia-extra-550-server : Conflicts: libnvidia-extra
#  libnvidia-extra-555 : Conflicts: libnvidia-extra
#  libnvidia-extra-560 : Conflicts: libnvidia-extra
#  libnvidia-extra-565 : Conflicts: libnvidia-extra
#  libnvidia-extra-565-server : Conflicts: libnvidia-extra
#  libnvidia-fbc1-390 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-418-server : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-450-server : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-470 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-470-server : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-515 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-520 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-525 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-535 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-535-server : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-545 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-550 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-550-server : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-555 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-560 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-565 : Conflicts: libnvidia-fbc1
#  libnvidia-fbc1-565-server : Conflicts: libnvidia-fbc1
#  libnvidia-gl-390 : Conflicts: libnvidia-gl
#  libnvidia-gl-418-server : Conflicts: libnvidia-gl
#  libnvidia-gl-450-server : Conflicts: libnvidia-gl
#  libnvidia-gl-470 : Conflicts: libnvidia-gl
#  libnvidia-gl-470-server : Conflicts: libnvidia-gl
#  libnvidia-gl-515 : Conflicts: libnvidia-gl
#  libnvidia-gl-520 : Conflicts: libnvidia-gl
#  libnvidia-gl-525 : Conflicts: libnvidia-gl
#  libnvidia-gl-535 : Conflicts: libnvidia-gl
#  libnvidia-gl-535-server : Conflicts: libnvidia-gl
#  libnvidia-gl-545 : Conflicts: libnvidia-gl
#  libnvidia-gl-550 : Conflicts: libnvidia-gl
#  libnvidia-gl-550-server : Conflicts: libnvidia-gl
#  libnvidia-gl-555 : Conflicts: libnvidia-gl
#  libnvidia-gl-560 : Conflicts: libnvidia-gl
#  libnvidia-gl-565 : Conflicts: libnvidia-egl-wayland1
#                     Conflicts: libnvidia-gl
#  libnvidia-gl-565-server : Conflicts: libnvidia-gl
#  libnvidia-ifr1-390 : Conflicts: libnvidia-ifr1
#  libnvidia-ifr1-418-server : Conflicts: libnvidia-ifr1
#  libnvidia-ifr1-450-server : Conflicts: libnvidia-ifr1
#  libnvidia-ifr1-470 : Conflicts: libnvidia-ifr1
#  libnvidia-ifr1-470-server : Conflicts: libnvidia-ifr1
#  libnvidia-nscq-450 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-470 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-515 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-520 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-525 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-530 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-535 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-545 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-550 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-555 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-560 : Conflicts: libnvidia-nscq
#  libnvidia-nscq-565 : Conflicts: libnvidia-nscq
#  libnvparsers-dev : Depends: libnvinfer-dev (= 8.6.1.6-1+cuda12.0) but 10.7.0.23-1+cuda12.6 is to be installed
#  libocct-data-exchange-dev : Conflicts: liboce-ocaf-dev but 0.18.3-2 is to be installed
#                              Conflicts: liboce-ocaf-lite-dev but 0.18.3-2 is to be installed
#  libocct-foundation-dev : Conflicts: liboce-foundation-dev but 0.18.3-2 is to be installed
#  libocct-modeling-algorithms-dev : Conflicts: liboce-modeling-dev but 0.18.3-2 is to be installed
#  libocct-modeling-data-dev : Conflicts: liboce-modeling-dev but 0.18.3-2 is to be installed
#  libocct-ocaf-dev : Conflicts: liboce-ocaf-dev but 0.18.3-2 is to be installed
#                     Conflicts: liboce-ocaf-lite-dev but 0.18.3-2 is to be installed
#  libocct-visualization-dev : Conflicts: liboce-visualization-dev but 0.18.3-2 is to be installed
#  libodc-dev : Conflicts: libodb-dev but 2.4.0-1ubuntu1 is to be installed
#  libogre-1.12-dev : Conflicts: libogre-1.9-dev but 1.9.0+dfsg1-12.1ubuntu1 is to be installed
#  libomp-11-dev : Conflicts: libomp-x.y-dev
#  libomp-12-dev : Conflicts: libomp-x.y-dev
#  libomp-13-dev : Conflicts: libomp-x.y-dev
#  libomp-14-dev : Conflicts: libomp-x.y-dev
#  libomp-15-dev : Conflicts: libomp-x.y-dev
#  libomp5-11 : Conflicts: libomp-x.y
#  libomp5-12 : Conflicts: libomp-x.y
#  libomp5-13 : Conflicts: libomp-x.y
#  libomp5-14 : Conflicts: libomp-x.y
#  libomp5-15 : Conflicts: libomp-x.y
#  libopencl-clang-12-dev : Conflicts: libopencl-clang-x.y-dev
#  libopencl-clang-dev : Conflicts: libopencl-clang-x.y-dev
#  libopenh264-cisco6 : Conflicts: libopenh264-6
#  libopenmpt-modplug-dev : Conflicts: libmodplug-dev but 1:0.8.9.0-3 is to be installed
#  libopenni-sensor-pointclouds-dev : Conflicts: libopenni-sensor-dev
#  libopenni-sensor-pointclouds0 : Conflicts: libopenni-sensor
#  libopenni-sensor-primesense-dev : Conflicts: libopenni-sensor-dev
#  libopenni-sensor-primesense0 : Conflicts: libopenni-sensor
#  liboss4-salsa-asound2 : Conflicts: libasound2
#  libossp-uuid-perl : Conflicts: libdata-uuid-perl
#  libotf-bin : Conflicts: otf-trace but 1.12.5+dfsg-8 is to be installed
#  libotf-trace-dev : Conflicts: libotf-dev but 0.9.16-3build1 is to be installed
#  libowfat-dev : Conflicts: libcdb-dev but 0.78build3 is to be installed
#                 Conflicts: libudt-dev but 4.11+dfsg1-1ubuntu2 is to be installed
#  libpam-heimdal : Conflicts: libpam-krb5 but 4.11-1build1 is to be installed
#  libpam-krb5 : Conflicts: libpam-heimdal but 4.11-1build1 is to be installed
#  libpam-ldapd : Conflicts: libpam-ldap
#  libpcp3 : Conflicts: pgpool2 but 4.1.4-6build1 is to be installed
#  libperl-critic-community-perl : Breaks: libperl-critic-freenode-perl (< 1.0.0)
#  libpgm-dev : Conflicts: libnetpbm9-dev but 2:10.0-15.4 is to be installed
#  libpgpool-dev : Conflicts: libpcp3-dev but 5.3.6-1build1 is to be installed
#  libpomp2-dev : Conflicts: libpomp-dev but 1.1+dfsg-9 is to be installed
#  libpsm-infinipath1-dev : Conflicts: libion-dev but 3.2.1+dfsg-1.1 is to be installed
#  libqt5gui5 : Conflicts: libqt5gui5-gles but 5.15.3+dfsg-1 is to be installed
#  libqt5gui5-gles : Conflicts: libqt5gui5 but 5.15.3+dfsg-2ubuntu0.2 is to be installed
#  libqt5quick5 : Conflicts: libqt5quick5-gles but 5.15.3+dfsg-1 is to be installed
#  libqt5quick5-gles : Conflicts: libqt5quick5 but 5.15.3+dfsg-1 is to be installed
#  libqt5quickparticles5 : Conflicts: libqt5quickparticles5-gles but 5.15.3+dfsg-1 is to be installed
#  libqt5quickparticles5-gles : Conflicts: libqt5quickparticles5 but 5.15.3+dfsg-1 is to be installed
#  librarian-puppet-simple : Conflicts: librarian-puppet but 3.0.0-2 is to be installed
#  librem5-tweaks : Conflicts: mobile-tweaks
#  libreoffice-base-nogui : Conflicts: libreoffice-base but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-calc-nogui : Conflicts: libreoffice-calc but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-core : Conflicts: libreoffice-core-nogui but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-core-nogui : Conflicts: libreoffice-core but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-calc but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-gtk2 but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-gtk3 but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-kde4 but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-kde5 but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-kf5 but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                           Breaks: libreoffice-qt5 but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-draw-nogui : Conflicts: libreoffice-draw but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-impress-nogui : Conflicts: libreoffice-impress but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-math-nogui : Conflicts: libreoffice-math but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-report-builder-bin-nogui : Conflicts: libreoffice-report-builder-bin but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-base : Breaks: libreoffice-base (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-base-nogui (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-calc : Breaks: libreoffice-calc (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-calc-nogui (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-common : Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-draw : Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-draw (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-draw-nogui (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-impress : Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                 Breaks: libreoffice-draw (< 4:7.6.0~rc1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                 Breaks: libreoffice-draw-nogui (< 4:7.6.0~rc1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                 Breaks: libreoffice-impress (< 4:7.6.0~rc1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                 Breaks: libreoffice-impress-nogui (< 4:7.6.0~rc1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-math : Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-math (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                              Breaks: libreoffice-math-nogui (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-report-builder : Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                        Breaks: libreoffice-report-builder (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-uiconfig-writer : Breaks: libreoffice-common (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                Breaks: libreoffice-writer (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#                                Breaks: libreoffice-writer-nogui (< 4:7.6.0~beta1) but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libreoffice-writer-nogui : Conflicts: libreoffice-writer but 1:7.3.7-0ubuntu0.22.04.7 is to be installed
#  libresteasy3.0-java : Conflicts: libresteasy-java but 3.6.2-2 is to be installed
#  libreswan : Conflicts: ike-server
#              Conflicts: strongswan-libcharon but 5.9.5-2ubuntu2.3 is to be installed
#              Conflicts: strongswan-starter but 5.9.5-2ubuntu2.3 is to be installed
#  librust-clap-2-dev : Breaks: librust-clap-2.33.3-dev
#  libsasl2-modules-gssapi-heimdal : Conflicts: libsasl2-modules-gssapi-mit but 2.1.27+dfsg2-3ubuntu1.2 is to be installed
#  libsasl2-modules-gssapi-mit : Conflicts: libsasl2-modules-gssapi-heimdal but 2.1.27+dfsg2-3ubuntu1.2 is to be installed
#  libscotchmetis-dev : Conflicts: libmetis-dev but 5.1.0.dfsg-7build2 is to be installed
#                       Conflicts: libparmetis-dev but 4.0.3-5build1 is to be installed
#  libscotchparmetis-dev : Conflicts: libparmetis-dev but 4.0.3-5build1 is to be installed
#  libsdl1.2-compat-dev : Conflicts: libsdl-dev
#                         Conflicts: libsdl1.2-dev
#  libsdl1.2-compat-shim : Conflicts: libsdl1.2debian
#  libsdl1.2-dev : Conflicts: libsdl-dev
#  libsendmail-pmilter-perl : Conflicts: libsendmail-milter-perl but 0.18-8build7 is to be installed
#  libsnack-alsa : Conflicts: libsnack-oss but 2.2.10.20090623-dfsg-10 is to be installed
#  libsnack-oss : Conflicts: libsnack-alsa but 2.2.10.20090623-dfsg-10 is to be installed
#  libsocl-1.3-0 : Conflicts: libsocl-contrib-1.3-0 but 1.3.9+dfsg-1 is to be installed
#  libsocl-contrib-1.3-0 : Conflicts: libsocl-1.3-0 but 1.3.9+dfsg-1 is to be installed
#  libsope-dev : Conflicts: libgnustep-dl2-dev but 0.12.0-15.1build6 is to be installed
#  libsrt-gnutls-dev : Conflicts: libsrt-openssl-dev but 1.4.4-4 is to be installed
#  libsrt-openssl-dev : Conflicts: libsrt-gnutls-dev but 1.4.4-4 is to be installed
#  libssh-dev : Conflicts: libssh-gcrypt-dev but 0.9.6-2ubuntu0.22.04.3 is to be installed
#  libssh-gcrypt-dev : Conflicts: libssh-dev but 0.9.6-2ubuntu0.22.04.3 is to be installed
#  libstarpu-1.3-8 : Conflicts: libstarpu-contrib-1.3-8 but 1.3.9+dfsg-1 is to be installed
#  libstarpu-contrib-1.3-8 : Conflicts: libstarpu-1.3-8 but 1.3.9+dfsg-1 is to be installed
#  libstarpu-contrib-dev : Conflicts: libstarpu-dev but 1.3.9+dfsg-1 is to be installed
#  libstarpu-contribfft-1.3-2 : Conflicts: libstarpufft-1.3-2 but 1.3.9+dfsg-1 is to be installed
#  libstarpu-contribmpi-1.3-3 : Conflicts: libstarpumpi-1.3-3 but 1.3.9+dfsg-1 is to be installed
#  libstarpu-contribrm-1.3-2 : Conflicts: libstarpurm-1.3-2 but 1.3.9+dfsg-1 is to be installed
#  libstarpu-dev : Conflicts: libstarpu-contrib-dev but 1.3.9+dfsg-1 is to be installed
#  libstarpufft-1.3-2 : Conflicts: libstarpu-contribfft-1.3-2 but 1.3.9+dfsg-1 is to be installed
#  libstarpumpi-1.3-3 : Conflicts: libstarpu-contribmpi-1.3-3 but 1.3.9+dfsg-1 is to be installed
#  libstarpurm-1.3-2 : Conflicts: libstarpu-contribrm-1.3-2 but 1.3.9+dfsg-1 is to be installed
#  libstdc++-10-doc : Conflicts: libstdc++-9-doc but 9.5.0-1ubuntu1~22.04 is to be installed
#  libstdc++-11-doc : Conflicts: libstdc++-10-doc but 10.5.0-1ubuntu1~22.04 is to be installed
#                     Conflicts: libstdc++-9-doc but 9.5.0-1ubuntu1~22.04 is to be installed
#  libstdc++-12-doc : Conflicts: libstdc++-10-doc but 10.5.0-1ubuntu1~22.04 is to be installed
#                     Conflicts: libstdc++-11-doc but 11.4.0-1ubuntu1~22.04 is to be installed
#                     Conflicts: libstdc++-9-doc but 9.5.0-1ubuntu1~22.04 is to be installed
#  libstdc++6-10-dbg : Conflicts: libstdc++6-9-dbg but 9.5.0-1ubuntu1~22.04 is to be installed
#  libstdc++6-11-dbg : Conflicts: libstdc++6-10-dbg but 10.5.0-1ubuntu1~22.04 is to be installed
#                      Conflicts: libstdc++6-9-dbg but 9.5.0-1ubuntu1~22.04 is to be installed
#  libstdc++6-11-dbg-alpha-cross : Conflicts: libstdc++6-10-dbg-alpha-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-amd64-cross : Conflicts: libstdc++6-10-dbg-amd64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-arm64-cross : Conflicts: libstdc++6-10-dbg-arm64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-armel-cross : Conflicts: libstdc++6-10-dbg-armel-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-armhf-cross : Conflicts: libstdc++6-10-dbg-armhf-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-hppa-cross : Conflicts: libstdc++6-10-dbg-hppa-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-i386-cross : Conflicts: libstdc++6-10-dbg-i386-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-m68k-cross : Conflicts: libstdc++6-10-dbg-m68k-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-powerpc-cross : Conflicts: libstdc++6-10-dbg-powerpc-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-ppc64-cross : Conflicts: libstdc++6-10-dbg-ppc64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-ppc64el-cross : Conflicts: libstdc++6-10-dbg-ppc64el-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-riscv64-cross : Conflicts: libstdc++6-10-dbg-riscv64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-s390x-cross : Conflicts: libstdc++6-10-dbg-s390x-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-sh4-cross : Conflicts: libstdc++6-10-dbg-sh4-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-sparc64-cross : Conflicts: libstdc++6-10-dbg-sparc64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-11-dbg-x32-cross : Conflicts: libstdc++6-10-dbg-x32-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg : Conflicts: libstdc++6-10-dbg but 10.5.0-1ubuntu1~22.04 is to be installed
#                      Conflicts: libstdc++6-11-dbg but 11.4.0-1ubuntu1~22.04 is to be installed
#                      Conflicts: libstdc++6-9-dbg but 9.5.0-1ubuntu1~22.04 is to be installed
#  libstdc++6-12-dbg-alpha-cross : Conflicts: libstdc++6-10-dbg-alpha-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-alpha-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-amd64-cross : Conflicts: libstdc++6-10-dbg-amd64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-amd64-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-arm64-cross : Conflicts: libstdc++6-10-dbg-arm64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-arm64-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-armel-cross : Conflicts: libstdc++6-10-dbg-armel-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-armel-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-armhf-cross : Conflicts: libstdc++6-10-dbg-armhf-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-armhf-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-hppa-cross : Conflicts: libstdc++6-10-dbg-hppa-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                 Conflicts: libstdc++6-11-dbg-hppa-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-i386-cross : Conflicts: libstdc++6-10-dbg-i386-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                 Conflicts: libstdc++6-11-dbg-i386-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-m68k-cross : Conflicts: libstdc++6-10-dbg-m68k-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                 Conflicts: libstdc++6-11-dbg-m68k-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-powerpc-cross : Conflicts: libstdc++6-10-dbg-powerpc-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                    Conflicts: libstdc++6-11-dbg-powerpc-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-ppc64-cross : Conflicts: libstdc++6-10-dbg-ppc64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-ppc64-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-ppc64el-cross : Conflicts: libstdc++6-10-dbg-ppc64el-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                    Conflicts: libstdc++6-11-dbg-ppc64el-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-riscv64-cross : Conflicts: libstdc++6-10-dbg-riscv64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                    Conflicts: libstdc++6-11-dbg-riscv64-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-s390x-cross : Conflicts: libstdc++6-10-dbg-s390x-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                  Conflicts: libstdc++6-11-dbg-s390x-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-sh4-cross : Conflicts: libstdc++6-10-dbg-sh4-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                Conflicts: libstdc++6-11-dbg-sh4-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-sparc64-cross : Conflicts: libstdc++6-10-dbg-sparc64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                    Conflicts: libstdc++6-11-dbg-sparc64-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libstdc++6-12-dbg-x32-cross : Conflicts: libstdc++6-10-dbg-x32-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                Conflicts: libstdc++6-11-dbg-x32-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libsvnclientadapter-java : Conflicts: libnb-svnclientadapter-java
#  libsvnclientadapter-java-doc : Conflicts: libnb-svnclientadapter-java-doc
#  libtbb2-dev : Conflicts: libtbb-dev but 2021.5.0-7ubuntu2 is to be installed
#  libtbb2-doc : Conflicts: libtbb-doc but 2021.5.0-7ubuntu2 is to be installed
#  libtestng7-java : Conflicts: testng but 6.9.12-4 is to be installed
#  libtext-markdown-perl : Conflicts: markdown but 1.0.1-10.1 is to be installed
#  libtomcatjss-java : Conflicts: libtcnative-1 but 1.2.31-1build1 is to be installed
#  libuhd4.1.0-dpdk : Conflicts: libuhd4.1.0
#  libunity-scopes-json-def-desktop : Conflicts: unity-scopes-json-def
#  libunity-scopes-json-def-phone : Conflicts: unity-scopes-json-def
#  libunwind-12 : Conflicts: libunwind-x.y
#  libunwind-12-dev : Conflicts: libunwind-x.y-dev
#                     Breaks: libunwind-dev
#  libunwind-13 : Conflicts: libunwind-x.y
#  libunwind-13-dev : Conflicts: libunwind-x.y-dev
#                     Breaks: libunwind-dev
#  libunwind-14 : Conflicts: libunwind-x.y
#  libunwind-14-dev : Conflicts: libunwind-x.y-dev
#                     Breaks: libunwind-dev
#  libunwind-15 : Conflicts: libunwind-x.y
#  libunwind-15-dev : Conflicts: libunwind-dev
#                     Conflicts: libunwind-x.y-dev
#  libvirt-daemon-system-systemd : Conflicts: libvirt-daemon-system-sysv but 8.0.0-1ubuntu7.10 is to be installed
#  libvulkan-volk-dev : Conflicts: libvolk2-dev but 2.5.1-1 is to be installed
#  libwnn6-dev : Conflicts: libwnn-dev but 1.1.1~a021+cvs20130302-7build1 is to be installed
#  libx32stdc++6-10-dbg : Conflicts: libx32stdc++6-9-dbg but 9.5.0-1ubuntu1~22.04 is to be installed
#  libx32stdc++6-11-dbg : Conflicts: libx32stdc++6-10-dbg but 10.5.0-1ubuntu1~22.04 is to be installed
#                         Conflicts: libx32stdc++6-9-dbg but 9.5.0-1ubuntu1~22.04 is to be installed
#  libx32stdc++6-11-dbg-amd64-cross : Conflicts: libx32stdc++6-10-dbg-amd64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libx32stdc++6-11-dbg-i386-cross : Conflicts: libx32stdc++6-10-dbg-i386-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#  libx32stdc++6-12-dbg : Conflicts: libx32stdc++6-10-dbg but 10.5.0-1ubuntu1~22.04 is to be installed
#                         Conflicts: libx32stdc++6-11-dbg but 11.4.0-1ubuntu1~22.04 is to be installed
#                         Conflicts: libx32stdc++6-9-dbg but 9.5.0-1ubuntu1~22.04 is to be installed
#  libx32stdc++6-12-dbg-amd64-cross : Conflicts: libx32stdc++6-10-dbg-amd64-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                     Conflicts: libx32stdc++6-11-dbg-amd64-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libx32stdc++6-12-dbg-i386-cross : Conflicts: libx32stdc++6-10-dbg-i386-cross but 10.5.0-1ubuntu1~22.04cross1 is to be installed
#                                    Conflicts: libx32stdc++6-11-dbg-i386-cross but 11.4.0-1ubuntu1~22.04cross1 is to be installed
#  libxaw3dxft8-dev : Conflicts: xpaint-dev but 2.9.1.4-4 is to be installed
#  libxbase64-bin : Conflicts: dvb-apps but 1.1.1+rev1500-1.4 is to be installed
#  libxdmf-dev : Conflicts: libloki-dev but 0.1.7-5ubuntu1 is to be installed
#  libyang2-dev : Conflicts: libyang-dev but 1.0.225-1.1 is to be installed
#  libzephyr4 : Conflicts: libzephyr4-krb5 but 3.1.2-1build3 is to be installed
#  libzephyr4-krb5 : Conflicts: libzephyr4
#  libzookeeper-mt-dev : Conflicts: libzookeeper-dev
#  libzookeeper-st-dev : Conflicts: libzookeeper-dev
#  linux-cloud-tools-nvidia-6.2 : Depends: linux-cloud-tools-6.2.0-1015-nvidia but it is not installable
#  linux-cloud-tools-nvidia-6.5 : Depends: linux-cloud-tools-6.5.0-1024-nvidia but it is not installable
#  linux-cloud-tools-nvidia-6.8 : Depends: linux-cloud-tools-6.8.0-1020-nvidia but it is not installable
#  linux-cloud-tools-nvidia-hwe-22.04 : Depends: linux-cloud-tools-6.8.0-1020-nvidia but it is not installable
#  linux-cloud-tools-nvidia-hwe-22.04-edge : Depends: linux-cloud-tools-6.8.0-1020-nvidia but it is not installable
#  linux-cloud-tools-nvidia-hwe-22.04-wip : Depends: linux-cloud-tools-6.8.0-1008-nvidia but it is not installable
#  linux-firmware : Conflicts: atmel-firmware
#  linux-image-5.15.0-100-generic : Conflicts: linux-image-unsigned-5.15.0-100-generic but 5.15.0-100.110 is to be installed
#  linux-image-5.15.0-100-lowlatency : Conflicts: linux-image-unsigned-5.15.0-100-lowlatency but 5.15.0-100.110 is to be installed
#  linux-image-5.15.0-1002-gke : Conflicts: linux-image-unsigned-5.15.0-1002-gke but 5.15.0-1002.2 is to be installed
#  linux-image-5.15.0-1002-ibm : Conflicts: linux-image-unsigned-5.15.0-1002-ibm but 5.15.0-1002.2 is to be installed
#  linux-image-5.15.0-1002-oracle : Conflicts: linux-image-unsigned-5.15.0-1002-oracle but 5.15.0-1002.4 is to be installed
#  linux-image-5.15.0-1003-azure : Conflicts: linux-image-unsigned-5.15.0-1003-azure but 5.15.0-1003.4 is to be installed
#  linux-image-5.15.0-1003-gcp : Conflicts: linux-image-unsigned-5.15.0-1003-gcp but 5.15.0-1003.6 is to be installed
#  linux-image-5.15.0-1004-aws : Conflicts: linux-image-unsigned-5.15.0-1004-aws but 5.15.0-1004.6 is to be installed
#  linux-image-5.15.0-1004-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1004-intel-iotg but 5.15.0-1004.6 is to be installed
#  linux-image-5.15.0-1004-kvm : Conflicts: linux-image-unsigned-5.15.0-1004-kvm but 5.15.0-1004.4 is to be installed
#  linux-image-5.15.0-101-generic : Conflicts: linux-image-unsigned-5.15.0-101-generic but 5.15.0-101.111 is to be installed
#  linux-image-5.15.0-101-lowlatency : Conflicts: linux-image-unsigned-5.15.0-101-lowlatency but 5.15.0-101.111 is to be installed
#  linux-image-5.15.0-1019-gkeop : Conflicts: linux-image-unsigned-5.15.0-1019-gkeop but 5.15.0-1019.24 is to be installed
#  linux-image-5.15.0-102-generic : Conflicts: linux-image-unsigned-5.15.0-102-generic but 5.15.0-102.112 is to be installed
#  linux-image-5.15.0-102-lowlatency : Conflicts: linux-image-unsigned-5.15.0-102-lowlatency but 5.15.0-102.112 is to be installed
#  linux-image-5.15.0-1020-gkeop : Conflicts: linux-image-unsigned-5.15.0-1020-gkeop but 5.15.0-1020.25 is to be installed
#  linux-image-5.15.0-1021-gkeop : Conflicts: linux-image-unsigned-5.15.0-1021-gkeop but 5.15.0-1021.26 is to be installed
#  linux-image-5.15.0-1022-gkeop : Conflicts: linux-image-unsigned-5.15.0-1022-gkeop but 5.15.0-1022.27 is to be installed
#  linux-image-5.15.0-1023-gkeop : Conflicts: linux-image-unsigned-5.15.0-1023-gkeop but 5.15.0-1023.28 is to be installed
#  linux-image-5.15.0-1024-gkeop : Conflicts: linux-image-unsigned-5.15.0-1024-gkeop but 5.15.0-1024.29 is to be installed
#  linux-image-5.15.0-1025-gkeop : Conflicts: linux-image-unsigned-5.15.0-1025-gkeop but 5.15.0-1025.30 is to be installed
#  linux-image-5.15.0-1025-nvidia : Conflicts: linux-image-unsigned-5.15.0-1025-nvidia but 5.15.0-1025.25 is to be installed
#  linux-image-5.15.0-1025-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1025-nvidia-lowlatency but 5.15.0-1025.25 is to be installed
#  linux-image-5.15.0-1026-gkeop : Conflicts: linux-image-unsigned-5.15.0-1026-gkeop but 5.15.0-1026.31 is to be installed
#  linux-image-5.15.0-1026-nvidia : Conflicts: linux-image-unsigned-5.15.0-1026-nvidia but 5.15.0-1026.26 is to be installed
#  linux-image-5.15.0-1026-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1026-nvidia-lowlatency but 5.15.0-1026.26 is to be installed
#  linux-image-5.15.0-1027-gke : Conflicts: linux-image-unsigned-5.15.0-1027-gke but 5.15.0-1027.32 is to be installed
#  linux-image-5.15.0-1027-gkeop : Conflicts: linux-image-unsigned-5.15.0-1027-gkeop but 5.15.0-1027.32 is to be installed
#  linux-image-5.15.0-1027-nvidia : Conflicts: linux-image-unsigned-5.15.0-1027-nvidia but 5.15.0-1027.27 is to be installed
#  linux-image-5.15.0-1027-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1027-nvidia-lowlatency but 5.15.0-1027.27 is to be installed
#  linux-image-5.15.0-1028-gke : Conflicts: linux-image-unsigned-5.15.0-1028-gke but 5.15.0-1028.33 is to be installed
#  linux-image-5.15.0-1028-gkeop : Conflicts: linux-image-unsigned-5.15.0-1028-gkeop but 5.15.0-1028.33 is to be installed
#  linux-image-5.15.0-1028-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1028-intel-iotg but 5.15.0-1028.33 is to be installed
#  linux-image-5.15.0-1028-nvidia : Conflicts: linux-image-unsigned-5.15.0-1028-nvidia but 5.15.0-1028.28 is to be installed
#  linux-image-5.15.0-1028-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1028-nvidia-lowlatency but 5.15.0-1028.28 is to be installed
#  linux-image-5.15.0-1029-nvidia : Conflicts: linux-image-unsigned-5.15.0-1029-nvidia but 5.15.0-1029.29 is to be installed
#  linux-image-5.15.0-1029-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1029-nvidia-lowlatency but 5.15.0-1029.29 is to be installed
#  linux-image-5.15.0-1030-gke : Conflicts: linux-image-unsigned-5.15.0-1030-gke but 5.15.0-1030.35 is to be installed
#  linux-image-5.15.0-1030-gkeop : Conflicts: linux-image-unsigned-5.15.0-1030-gkeop but 5.15.0-1030.35 is to be installed
#  linux-image-5.15.0-1030-ibm : Conflicts: linux-image-unsigned-5.15.0-1030-ibm but 5.15.0-1030.33 is to be installed
#  linux-image-5.15.0-1030-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1030-intel-iotg but 5.15.0-1030.35 is to be installed
#  linux-image-5.15.0-1030-nvidia : Conflicts: linux-image-unsigned-5.15.0-1030-nvidia but 5.15.0-1030.30 is to be installed
#  linux-image-5.15.0-1030-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1030-nvidia-lowlatency but 5.15.0-1030.30 is to be installed
#  linux-image-5.15.0-1031-gkeop : Conflicts: linux-image-unsigned-5.15.0-1031-gkeop but 5.15.0-1031.37 is to be installed
#  linux-image-5.15.0-1031-ibm : Conflicts: linux-image-unsigned-5.15.0-1031-ibm but 5.15.0-1031.34 is to be installed
#  linux-image-5.15.0-1031-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1031-intel-iotg but 5.15.0-1031.36 is to be installed
#  linux-image-5.15.0-1031-nvidia : Conflicts: linux-image-unsigned-5.15.0-1031-nvidia but 5.15.0-1031.31 is to be installed
#  linux-image-5.15.0-1031-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1031-nvidia-lowlatency but 5.15.0-1031.31 is to be installed
#  linux-image-5.15.0-1032-gke : Conflicts: linux-image-unsigned-5.15.0-1032-gke but 5.15.0-1032.37 is to be installed
#  linux-image-5.15.0-1032-gkeop : Conflicts: linux-image-unsigned-5.15.0-1032-gkeop but 5.15.0-1032.38 is to be installed
#  linux-image-5.15.0-1032-ibm : Conflicts: linux-image-unsigned-5.15.0-1032-ibm but 5.15.0-1032.35 is to be installed
#  linux-image-5.15.0-1032-nvidia : Conflicts: linux-image-unsigned-5.15.0-1032-nvidia but 5.15.0-1032.32 is to be installed
#  linux-image-5.15.0-1032-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1032-nvidia-lowlatency but 5.15.0-1032.32 is to be installed
#  linux-image-5.15.0-1032-realtime : Conflicts: linux-image-unsigned-5.15.0-1032-realtime but 5.15.0-1032.35 is to be installed
#  linux-image-5.15.0-1033-gke : Conflicts: linux-image-unsigned-5.15.0-1033-gke but 5.15.0-1033.38 is to be installed
#  linux-image-5.15.0-1033-gkeop : Conflicts: linux-image-unsigned-5.15.0-1033-gkeop but 5.15.0-1033.39 is to be installed
#  linux-image-5.15.0-1033-ibm : Conflicts: linux-image-unsigned-5.15.0-1033-ibm but 5.15.0-1033.36 is to be installed
#  linux-image-5.15.0-1033-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1033-intel-iotg but 5.15.0-1033.38 is to be installed
#  linux-image-5.15.0-1033-kvm : Conflicts: linux-image-unsigned-5.15.0-1033-kvm but 5.15.0-1033.38 is to be installed
#  linux-image-5.15.0-1033-nvidia : Conflicts: linux-image-unsigned-5.15.0-1033-nvidia but 5.15.0-1033.33 is to be installed
#  linux-image-5.15.0-1033-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1033-nvidia-lowlatency but 5.15.0-1033.33 is to be installed
#  linux-image-5.15.0-1034-gcp : Conflicts: linux-image-unsigned-5.15.0-1034-gcp but 5.15.0-1034.42 is to be installed
#  linux-image-5.15.0-1034-gke : Conflicts: linux-image-unsigned-5.15.0-1034-gke but 5.15.0-1034.39 is to be installed
#  linux-image-5.15.0-1034-gkeop : Conflicts: linux-image-unsigned-5.15.0-1034-gkeop but 5.15.0-1034.40 is to be installed
#  linux-image-5.15.0-1034-ibm : Conflicts: linux-image-unsigned-5.15.0-1034-ibm but 5.15.0-1034.37 is to be installed
#  linux-image-5.15.0-1034-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1034-intel-iotg but 5.15.0-1034.39 is to be installed
#  linux-image-5.15.0-1034-kvm : Conflicts: linux-image-unsigned-5.15.0-1034-kvm but 5.15.0-1034.39 is to be installed
#  linux-image-5.15.0-1035-aws : Conflicts: linux-image-unsigned-5.15.0-1035-aws but 5.15.0-1035.39 is to be installed
#  linux-image-5.15.0-1035-azure : Conflicts: linux-image-unsigned-5.15.0-1035-azure but 5.15.0-1035.42 is to be installed
#  linux-image-5.15.0-1035-gcp : Conflicts: linux-image-unsigned-5.15.0-1035-gcp but 5.15.0-1035.43 is to be installed
#  linux-image-5.15.0-1035-gke : Conflicts: linux-image-unsigned-5.15.0-1035-gke but 5.15.0-1035.40 is to be installed
#  linux-image-5.15.0-1035-gkeop : Conflicts: linux-image-unsigned-5.15.0-1035-gkeop but 5.15.0-1035.41 is to be installed
#  linux-image-5.15.0-1035-ibm : Conflicts: linux-image-unsigned-5.15.0-1035-ibm but 5.15.0-1035.38 is to be installed
#  linux-image-5.15.0-1035-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1035-intel-iotg but 5.15.0-1035.40 is to be installed
#  linux-image-5.15.0-1035-kvm : Conflicts: linux-image-unsigned-5.15.0-1035-kvm but 5.15.0-1035.40 is to be installed
#  linux-image-5.15.0-1035-oracle : Conflicts: linux-image-unsigned-5.15.0-1035-oracle but 5.15.0-1035.41 is to be installed
#  linux-image-5.15.0-1036-aws : Conflicts: linux-image-unsigned-5.15.0-1036-aws but 5.15.0-1036.40 is to be installed
#  linux-image-5.15.0-1036-azure : Conflicts: linux-image-unsigned-5.15.0-1036-azure but 5.15.0-1036.43 is to be installed
#  linux-image-5.15.0-1036-gcp : Conflicts: linux-image-unsigned-5.15.0-1036-gcp but 5.15.0-1036.44 is to be installed
#  linux-image-5.15.0-1036-gke : Conflicts: linux-image-unsigned-5.15.0-1036-gke but 5.15.0-1036.41 is to be installed
#  linux-image-5.15.0-1036-gkeop : Conflicts: linux-image-unsigned-5.15.0-1036-gkeop but 5.15.0-1036.42 is to be installed
#  linux-image-5.15.0-1036-ibm : Conflicts: linux-image-unsigned-5.15.0-1036-ibm but 5.15.0-1036.39 is to be installed
#  linux-image-5.15.0-1036-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1036-intel-iotg but 5.15.0-1036.41 is to be installed
#  linux-image-5.15.0-1036-oracle : Conflicts: linux-image-unsigned-5.15.0-1036-oracle but 5.15.0-1036.42 is to be installed
#  linux-image-5.15.0-1037-aws : Conflicts: linux-image-unsigned-5.15.0-1037-aws but 5.15.0-1037.41 is to be installed
#  linux-image-5.15.0-1037-azure : Conflicts: linux-image-unsigned-5.15.0-1037-azure but 5.15.0-1037.44 is to be installed
#  linux-image-5.15.0-1037-azure-fde : Conflicts: linux-image-unsigned-5.15.0-1037-azure-fde but 5.15.0-1037.44.1 is to be installed
#  linux-image-5.15.0-1037-gcp : Conflicts: linux-image-unsigned-5.15.0-1037-gcp but 5.15.0-1037.45 is to be installed
#  linux-image-5.15.0-1037-gke : Conflicts: linux-image-unsigned-5.15.0-1037-gke but 5.15.0-1037.42 is to be installed
#  linux-image-5.15.0-1037-gkeop : Conflicts: linux-image-unsigned-5.15.0-1037-gkeop but 5.15.0-1037.43 is to be installed
#  linux-image-5.15.0-1037-ibm : Conflicts: linux-image-unsigned-5.15.0-1037-ibm but 5.15.0-1037.40 is to be installed
#  linux-image-5.15.0-1037-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1037-intel-iotg but 5.15.0-1037.42 is to be installed
#  linux-image-5.15.0-1037-kvm : Conflicts: linux-image-unsigned-5.15.0-1037-kvm but 5.15.0-1037.42 is to be installed
#  linux-image-5.15.0-1037-nvidia : Conflicts: linux-image-unsigned-5.15.0-1037-nvidia but 5.15.0-1037.37 is to be installed
#  linux-image-5.15.0-1037-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1037-nvidia-lowlatency but 5.15.0-1037.37 is to be installed
#  linux-image-5.15.0-1037-oracle : Conflicts: linux-image-unsigned-5.15.0-1037-oracle but 5.15.0-1037.43 is to be installed
#  linux-image-5.15.0-1038-aws : Conflicts: linux-image-unsigned-5.15.0-1038-aws but 5.15.0-1038.43 is to be installed
#  linux-image-5.15.0-1038-azure : Conflicts: linux-image-unsigned-5.15.0-1038-azure but 5.15.0-1038.45 is to be installed
#  linux-image-5.15.0-1038-azure-fde : Conflicts: linux-image-unsigned-5.15.0-1038-azure-fde but 5.15.0-1038.45.1 is to be installed
#  linux-image-5.15.0-1038-gcp : Conflicts: linux-image-unsigned-5.15.0-1038-gcp but 5.15.0-1038.46 is to be installed
#  linux-image-5.15.0-1038-gke : Conflicts: linux-image-unsigned-5.15.0-1038-gke but 5.15.0-1038.43 is to be installed
#  linux-image-5.15.0-1038-gkeop : Conflicts: linux-image-unsigned-5.15.0-1038-gkeop but 5.15.0-1038.44 is to be installed
#  linux-image-5.15.0-1038-ibm : Conflicts: linux-image-unsigned-5.15.0-1038-ibm but 5.15.0-1038.41 is to be installed
#  linux-image-5.15.0-1038-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1038-intel-iotg but 5.15.0-1038.43 is to be installed
#  linux-image-5.15.0-1038-kvm : Conflicts: linux-image-unsigned-5.15.0-1038-kvm but 5.15.0-1038.43 is to be installed
#  linux-image-5.15.0-1038-oracle : Conflicts: linux-image-unsigned-5.15.0-1038-oracle but 5.15.0-1038.44 is to be installed
#  linux-image-5.15.0-1039-aws : Conflicts: linux-image-unsigned-5.15.0-1039-aws but 5.15.0-1039.44 is to be installed
#  linux-image-5.15.0-1039-azure : Conflicts: linux-image-unsigned-5.15.0-1039-azure but 5.15.0-1039.46 is to be installed
#  linux-image-5.15.0-1039-azure-fde : Conflicts: linux-image-unsigned-5.15.0-1039-azure-fde but 5.15.0-1039.46.1 is to be installed
#  linux-image-5.15.0-1039-gcp : Conflicts: linux-image-unsigned-5.15.0-1039-gcp but 5.15.0-1039.47 is to be installed
#  linux-image-5.15.0-1039-gke : Conflicts: linux-image-unsigned-5.15.0-1039-gke but 5.15.0-1039.44 is to be installed
#  linux-image-5.15.0-1039-gkeop : Conflicts: linux-image-unsigned-5.15.0-1039-gkeop but 5.15.0-1039.45 is to be installed
#  linux-image-5.15.0-1039-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1039-intel-iotg but 5.15.0-1039.45 is to be installed
#  linux-image-5.15.0-1039-kvm : Conflicts: linux-image-unsigned-5.15.0-1039-kvm but 5.15.0-1039.44 is to be installed
#  linux-image-5.15.0-1039-nvidia : Conflicts: linux-image-unsigned-5.15.0-1039-nvidia but 5.15.0-1039.39 is to be installed
#  linux-image-5.15.0-1039-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1039-nvidia-lowlatency but 5.15.0-1039.39 is to be installed
#  linux-image-5.15.0-1039-oracle : Conflicts: linux-image-unsigned-5.15.0-1039-oracle but 5.15.0-1039.45 is to be installed
#  linux-image-5.15.0-1040-aws : Conflicts: linux-image-unsigned-5.15.0-1040-aws but 5.15.0-1040.45 is to be installed
#  linux-image-5.15.0-1040-azure : Conflicts: linux-image-unsigned-5.15.0-1040-azure but 5.15.0-1040.47 is to be installed
#  linux-image-5.15.0-1040-gcp : Conflicts: linux-image-unsigned-5.15.0-1040-gcp but 5.15.0-1040.48 is to be installed
#  linux-image-5.15.0-1040-gke : Conflicts: linux-image-unsigned-5.15.0-1040-gke but 5.15.0-1040.45 is to be installed
#  linux-image-5.15.0-1040-gkeop : Conflicts: linux-image-unsigned-5.15.0-1040-gkeop but 5.15.0-1040.46 is to be installed
#  linux-image-5.15.0-1040-ibm : Conflicts: linux-image-unsigned-5.15.0-1040-ibm but 5.15.0-1040.43 is to be installed
#  linux-image-5.15.0-1040-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1040-intel-iotg but 5.15.0-1040.46 is to be installed
#  linux-image-5.15.0-1040-kvm : Conflicts: linux-image-unsigned-5.15.0-1040-kvm but 5.15.0-1040.45 is to be installed
#  linux-image-5.15.0-1040-nvidia : Conflicts: linux-image-unsigned-5.15.0-1040-nvidia but 5.15.0-1040.40 is to be installed
#  linux-image-5.15.0-1040-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1040-nvidia-lowlatency but 5.15.0-1040.40 is to be installed
#  linux-image-5.15.0-1040-oracle : Conflicts: linux-image-unsigned-5.15.0-1040-oracle but 5.15.0-1040.46 is to be installed
#  linux-image-5.15.0-1041-azure : Conflicts: linux-image-unsigned-5.15.0-1041-azure but 5.15.0-1041.48 is to be installed
#  linux-image-5.15.0-1041-azure-fde : Conflicts: linux-image-unsigned-5.15.0-1041-azure-fde but 5.15.0-1041.48.1 is to be installed
#  linux-image-5.15.0-1041-gcp : Conflicts: linux-image-unsigned-5.15.0-1041-gcp but 5.15.0-1041.49 is to be installed
#  linux-image-5.15.0-1041-gke : Conflicts: linux-image-unsigned-5.15.0-1041-gke but 5.15.0-1041.46 is to be installed
#  linux-image-5.15.0-1041-ibm : Conflicts: linux-image-unsigned-5.15.0-1041-ibm but 5.15.0-1041.44 is to be installed
#  linux-image-5.15.0-1041-kvm : Conflicts: linux-image-unsigned-5.15.0-1041-kvm but 5.15.0-1041.46 is to be installed
#  linux-image-5.15.0-1041-nvidia : Conflicts: linux-image-unsigned-5.15.0-1041-nvidia but 5.15.0-1041.41 is to be installed
#  linux-image-5.15.0-1041-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1041-nvidia-lowlatency but 5.15.0-1041.41 is to be installed
#  linux-image-5.15.0-1041-oracle : Conflicts: linux-image-unsigned-5.15.0-1041-oracle but 5.15.0-1041.47 is to be installed
#  linux-image-5.15.0-1042-aws : Conflicts: linux-image-unsigned-5.15.0-1042-aws but 5.15.0-1042.47 is to be installed
#  linux-image-5.15.0-1042-azure : Conflicts: linux-image-unsigned-5.15.0-1042-azure but 5.15.0-1042.49 is to be installed
#  linux-image-5.15.0-1042-azure-fde : Conflicts: linux-image-unsigned-5.15.0-1042-azure-fde but 5.15.0-1042.49.1 is to be installed
#  linux-image-5.15.0-1042-gcp : Conflicts: linux-image-unsigned-5.15.0-1042-gcp but 5.15.0-1042.50 is to be installed
#  linux-image-5.15.0-1042-gke : Conflicts: linux-image-unsigned-5.15.0-1042-gke but 5.15.0-1042.47 is to be installed
#  linux-image-5.15.0-1042-ibm : Conflicts: linux-image-unsigned-5.15.0-1042-ibm but 5.15.0-1042.45 is to be installed
#  linux-image-5.15.0-1042-kvm : Conflicts: linux-image-unsigned-5.15.0-1042-kvm but 5.15.0-1042.47 is to be installed
#  linux-image-5.15.0-1042-nvidia : Conflicts: linux-image-unsigned-5.15.0-1042-nvidia but 5.15.0-1042.42 is to be installed
#  linux-image-5.15.0-1042-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1042-nvidia-lowlatency but 5.15.0-1042.42 is to be installed
#  linux-image-5.15.0-1042-oracle : Conflicts: linux-image-unsigned-5.15.0-1042-oracle but 5.15.0-1042.48 is to be installed
#  linux-image-5.15.0-1043-aws : Conflicts: linux-image-unsigned-5.15.0-1043-aws but 5.15.0-1043.48 is to be installed
#  linux-image-5.15.0-1043-gkeop : Conflicts: linux-image-unsigned-5.15.0-1043-gkeop but 5.15.0-1043.50 is to be installed
#  linux-image-5.15.0-1043-ibm : Conflicts: linux-image-unsigned-5.15.0-1043-ibm but 5.15.0-1043.46 is to be installed
#  linux-image-5.15.0-1043-intel-iotg : Conflicts: linux-image-unsigned-5.15.0-1043-intel-iotg but 5.15.0-1043.49 is to be installed
#  linux-image-5.15.0-1043-nvidia : Conflicts: linux-image-unsigned-5.15.0-1043-nvidia but 5.15.0-1043.43 is to be installed
#  linux-image-5.15.0-1043-nvidia-lowlatency : Conflicts: linux-image-unsigned-5.15.0-1043-nvidia-lowlatency but 5.15.0-1043.43 is to be installed
#  linux-image-5.15.0-1044-aws : Conflicts: linux-image-unsigned-5.15.0-1044-aws but 5.15.0-1044.49 is to be installed
#  linux-image-5.15.0-1044-azure : Conflicts: linux-image-unsigned-5.15.0-1044-azure but 5.15.0-1044.51 is to be installed
#  linux-image-5.15.0-1044-azure-fde : Conflicts: linux-image-unsigned-5.15.0-1044-azure-fde but 5.15.0-1044.51.1 is to be installed
#  linux-image-5.15.0-1044-gcp : Conflicts: linux-image-unsigned-5.15.0-1044-gcp but 5.15.0-1044.52 is to be installed
#  linux-image-5.15.0-1044-gke : Conflicts: linux-image-unsigned-5.15.0-1044-gke but 5.15.0-1044.49 is to be installed
# ...
#  qpdfview-pdf-poppler-plugin : Conflicts: qpdfview-pdf-mupdf-plugin but 0.4.18-6 is to be installed
#  qtbase5-dev : Conflicts: qtbase5-gles-dev but 5.15.3+dfsg-1 is to be installed
#  qtbase5-gles-dev : Conflicts: qtbase5-dev but 5.15.3+dfsg-2ubuntu0.2 is to be installed
#  qtbase5-private-dev : Conflicts: qtbase5-private-gles-dev but 5.15.3+dfsg-1 is to be installed
#  qtbase5-private-gles-dev : Conflicts: qtbase5-private-dev but 5.15.3+dfsg-2ubuntu0.2 is to be installed
#  r-base-core-dbg : Depends: r-base-core (= 4.1.2-1ubuntu2) but 4.4.2-1.2204.0 is to be installed
#                    Depends: r-base-dev (= 4.1.2-1ubuntu2) but 4.4.2-1.2204.0 is to be installed
#  rdnssd : Conflicts: network-manager but 1.36.6-0ubuntu2 is to be installed
#  reboot-notifier : Conflicts: update-notifier-common but 3.192.54.8 is to be installed
#  relion : Conflicts: relion-cuda but 3.1.0-2 is to be installed
#  relion-cuda : Conflicts: relion but 3.1.3-1 is to be installed
#  relion-gui-cuda : Conflicts: relion-gui but 3.1.3-1 is to be installed
#  rime-data-emoji : Breaks: librime-data-emoji
#  rlinetd : Conflicts: inet-superserver
#            Conflicts: xinetd but 1:2.3.15.3-1 is to be installed
#  rmail : Conflicts: courier-mta but 1.0.16-3build3 is to be installed
#          Conflicts: exim4 but 4.95-4ubuntu2.6 is to be installed
#          Conflicts: exim4-daemon-heavy but 4.95-4ubuntu2.6 is to be installed
#          Conflicts: exim4-daemon-light but 4.95-4ubuntu2.6 is to be installed
#          Conflicts: masqmail but 0.3.4-1build1 is to be installed
#          Conflicts: postfix but 3.6.4-1ubuntu1.3 is to be installed
#  rng-tools5 : Conflicts: rng-tools
#  rsh-redone-server : Conflicts: rsh-server
#  rsyslog : Conflicts: linux-kernel-log-daemon
#            Conflicts: system-log-daemon
#  ruby-celluloid-essentials : Breaks: ruby-celluloid (< 0.17~) but 0.16.0-5 is to be installed
#  ruby-celluloid-extras : Breaks: ruby-celluloid (< 0.17~) but 0.16.0-5 is to be installed
#  ruby-celluloid-fsm : Breaks: ruby-celluloid (< 0.17~) but 0.16.0-5 is to be installed
#  ruby-celluloid-pool : Breaks: ruby-celluloid (< 0.17~) but 0.16.0-5 is to be installed
#  ruby-celluloid-supervision : Breaks: ruby-celluloid (< 0.17~) but 0.16.0-5 is to be installed
#  ruby-launchy : Breaks: ruby-launchy-shim
#  rust-1.76-lldb : Depends: lldb-17 but it is not installable
#                   Depends: python3-lldb-17 but it is not installable
#  rust-1.77-lldb : Depends: lldb-17 but it is not installable
#                   Depends: python3-lldb-17 but it is not installable
#  rust-1.78-lldb : Depends: lldb-18 but it is not installable
#                   Depends: python3-lldb-18 but it is not installable
#  rust-1.79-lldb : Depends: lldb-18 but it is not installable
#                   Depends: python3-lldb-18 but it is not installable
#  rust-1.80-lldb : Depends: lldb-18 but it is not installable
#                   Depends: python3-lldb-18 but it is not installable
#  rust-lldb : Depends: lldb-17 but it is not installable
#              Depends: python3-lldb-17 but it is not installable
#  sabily-grub-artwork : Conflicts: desktop-base but 11.0.3ubuntu1 is to be installed
#  scid-rating-data : Conflicts: scid-spell-data but 200901-3 is to be installed
#  scid-spell-data : Conflicts: scid-rating-data but 200901-3 is to be installed
#  selinux-policy-default : Conflicts: mcstrans but 3.3-1 is to be installed
#  selinux-policy-mls : Conflicts: mcstrans but 3.3-1 is to be installed
#  sendmail-bin : Conflicts: mail-transport-agent
#  shorewall-lite : Conflicts: ferm but 2.5.1-1 is to be installed
#                   Conflicts: filtergen but 0.12.8-1 is to be installed
#                   Conflicts: guidedog but 1.3.0-1build1 is to be installed
#                   Conflicts: uif but 1.1.9-5 is to be installed
#  shorewall6-lite : Conflicts: ferm but 2.5.1-1 is to be installed
#                    Conflicts: filtergen but 0.12.8-1 is to be installed
#                    Conflicts: guidedog but 1.3.0-1build1 is to be installed
#                    Conflicts: uif but 1.1.9-5 is to be installed
#  skksearch : Conflicts: skkserv
#  slurm-wlm-torque : Conflicts: gridengine-client but 8.1.9+dfsg-10build1 is to be installed
#  smcroute : Conflicts: pimd but 2.3.2-3 is to be installed
#  socklog-run : Conflicts: linux-kernel-log-daemon
#                Conflicts: system-log-daemon
#  solid-pop3d : Conflicts: pop3-server
#  spacefm : Conflicts: spacefm-gtk3 but 1.0.6-5build1 is to be installed
#  spacefm-gtk3 : Conflicts: spacefm but 1.0.6-5build1 is to be installed
#                 Conflicts: spacefm-hal
#  sqlite3-tools : Conflicts: emboss but 6.6.0+dfsg-11ubuntu1 is to be installed
#  squeezelite : Conflicts: squeezelite-pa but 1.9.9-1395+git20220104.874e4f9-1 is to be installed
#                Conflicts: squeezelite-pulseaudio but 1.9.9-1395+git20220104.874e4f9-1 is to be installed
#  squeezelite-pa : Conflicts: squeezelite
#                   Conflicts: squeezelite-pulseaudio but 1.9.9-1395+git20220104.874e4f9-1 is to be installed
#  squeezelite-pulseaudio : Conflicts: squeezelite
#                           Conflicts: squeezelite-pa but 1.9.9-1395+git20220104.874e4f9-1 is to be installed
#  squid : Conflicts: squid-openssl but 5.9-0ubuntu0.22.04.2 is to be installed
#  squid-openssl : Conflicts: squid but 5.9-0ubuntu0.22.04.2 is to be installed
#  sshfs : Breaks: fuse (< 3)
#  sslh : Conflicts: libnet-proxy-perl but 0.12-6.2 is to be installed
#  ssmtp : Conflicts: mail-transport-agent
#  starpu-contrib-examples : Conflicts: starpu-examples but 1.3.9+dfsg-1 is to be installed
#  starpu-contrib-tools : Conflicts: starpu-tools but 1.3.9+dfsg-1 is to be installed
#  starpu-examples : Conflicts: starpu-contrib-examples but 1.3.9+dfsg-1 is to be installed
#  starpu-tools : Conflicts: starpu-contrib-tools but 1.3.9+dfsg-1 is to be installed
#  steam-installer : Depends: steam (>= 1:1.0.0.74-1ubuntu2) but it is not installable
#  sudo : Conflicts: sudo-ldap but 1.9.9-1ubuntu2.4 is to be installed
#  sudo-ldap : Conflicts: sudo
#  syslog-ng-core : Conflicts: linux-kernel-log-daemon
#                   Conflicts: system-log-daemon
#  systemctl : Conflicts: systemd but 249.11-0ubuntu3.12 is to be installed
#  systemd-coredump : Conflicts: core-dump-handler
#  systemd-cron : Conflicts: anacron
#                 Conflicts: cron-daemon
#  systemd-standalone-sysusers : Conflicts: systemd-sysusers
#  systemd-standalone-tmpfiles : Conflicts: systemd-tmpfiles
#  systemd-timesyncd : Conflicts: time-daemon
#  tar-scripts : Conflicts: dump but 0.4b47-3 is to be installed
#                Conflicts: openafs-client but 1.8.10-2ubuntu1~22.04.2 is to be installed
#  tcl-itcl4-dev : Conflicts: itcl3-dev but 3.4.3-3.1 is to be installed
#                  Conflicts: tcl-itcl-dev
#  tcl-itcl4-doc : Conflicts: itcl-doc
#                  Conflicts: tcl-itcl-doc
#  tcpflow : Conflicts: tcpflow-nox but 1.6.1-2build1 is to be installed
#  tcpflow-nox : Conflicts: tcpflow
#  telnetd-ssl : Conflicts: telnetd but 0.17-44build1 is to be installed
#  texlive-fonts-extra : Conflicts: scalable-cyrfonts-tex but 4.18 is to be installed
#  tftp-hpa : Conflicts: tftp but 0.17-23ubuntu1 is to be installed
#  tftpd-hpa : Conflicts: atftpd but 0.7.git20210915-4build1 is to be installed
#              Conflicts: tftpd but 0.17-23ubuntu1 is to be installed
#  tiny-initramfs : Conflicts: dracut but 051-1 is to be installed
#                   Conflicts: initramfs-tools but 0.140ubuntu13.4 is to be installed
#                   Conflicts: live-tools but 1:20190831build1 is to be installed
#  tk-itk4-dev : Conflicts: itk3-dev but 3.4.2-3.1 is to be installed
#                Conflicts: tk-itk-dev
#  tk-itk4-doc : Conflicts: itk-doc
#                Conflicts: tk-itk-doc
#  tlp : Conflicts: laptop-mode-tools but 1.74-1.1 is to be installed
#  topydo : Conflicts: devtodo but 0.1.20+git20200830.0ad52b0-1 is to be installed
#  twoftpd-run : Conflicts: ftp-server
#  ubiquity-slideshow-kubuntu : Conflicts: ubiquity-slideshow
#  ubiquity-slideshow-ubuntu : Conflicts: ubiquity-slideshow
#  ubiquity-slideshow-ubuntu-budgie : Conflicts: ubiquity-slideshow
#  ubiquity-slideshow-ubuntu-mate : Conflicts: ubiquity-slideshow
#  ubiquity-slideshow-ubuntukylin : Conflicts: ubiquity-slideshow
#  ubiquity-slideshow-ubuntustudio : Conflicts: ubiquity-slideshow
#  ubiquity-slideshow-xubuntu : Conflicts: ubiquity-slideshow
#  ubuntu-business-defaults : Conflicts: ubuntu-default-settings
#  ubuntu-defaults-it : Conflicts: ubuntu-default-settings
#  ubuntu-defaults-nl-nl : Conflicts: ubuntu-default-settings
#  ubuntu-defaults-zh-cn : Conflicts: ubuntu-default-settings
#  ubuntu-mate-default-settings : Conflicts: debian-mate-default-settings but 1.26.0-1ubuntu1 is to be installed
#  ubuntukylin-default-settings : Conflicts: ubuntu-default-settings
#  ubuntustudio-default-settings : Conflicts: kubuntu-settings-desktop but 1:22.04.10 is to be installed
#  ubuntustudio-live : Conflicts: ubiquity-slideshow-kubuntu but 181.1 is to be installed
#                      Conflicts: ubiquity-slideshow-ubuntu but 181.1 is to be installed
#                      Conflicts: ubiquity-slideshow-xubuntu but 181.1 is to be installed
#  ubuntustudio-wallpapers-focal : Conflicts: ubuntustudio-wallpapers-jammy
#  ucspi-tcp-ipv6 : Conflicts: ucspi-tcp
#  udns-utils : Conflicts: rblcheck but 20190930-1 is to be installed
#  uglifyjs : Conflicts: node-uglify but 2.8.29-8 is to be installed
#  uif : Conflicts: shorewall but 5.2.3.4-1 is to be installed
#  ukui-settings-daemon : Conflicts: kylin-display-switch but 3.0.14-1 is to be installed
#  ukui-themes : Conflicts: ubuntukylin-theme but 3.0.2 is to be installed
#  unity-gtk2-module : Conflicts: appmenu-gtk
#  unity-gtk3-module : Conflicts: appmenu-gtk3
#  unity-scope-home : Conflicts: unity-scope-soundcloud
#                     Conflicts: unity-scope-yahoostock
#  unixodbc-dev : Conflicts: libiodbc2-dev but 3.52.9-2.1 is to be installed
#  unscd : Conflicts: nscd
#  urjtag : Conflicts: openwince-jtag but 0.5.1-8 is to be installed
#  uruk : Conflicts: ufw but 0.36.1-4ubuntu0.1 is to be installed
#  uucpsend : Conflicts: inn2 but 2.6.4-2build4 is to be installed
#  virtualbox-guest-utils-hwe : Conflicts: virtualbox-guest-utils
#  virtualbox-guest-x11-hwe : Conflicts: virtualbox-guest-x11
#  vsftpd : Conflicts: ftp-server
#  w3m-el : Conflicts: w3m-el-snapshot but 1.4.632+0.20210805.2351.f77da8b-1 is to be installed
#  w3m-el-snapshot : Conflicts: w3m-el
#  wmnd : Conflicts: wmnd-snmp but 0.4.18-1build2 is to be installed
#  wmnd-snmp : Conflicts: wmnd but 0.4.18-1build2 is to be installed
#  x2gothinclient-minidesktop : Conflicts: x2gothinclient
#  xabacus : Conflicts: xabacus
#  xinetd : Conflicts: inet-superserver
#  xmabacus : Conflicts: xabacus
#  xmakemol : Conflicts: xmakemol-gl but 5.16-10 is to be installed
#  xmakemol-gl : Conflicts: xmakemol but 5.16-10 is to be installed
#  xmlformat-perl : Conflicts: xmlformat
#  xmlformat-ruby : Conflicts: xmlformat
#  xmpuzzles : Conflicts: xpuzzles but 7.7.1-1.1 is to be installed
#  xpuzzles : Conflicts: xmpuzzles but 7.7.1-1.1 is to be installed
#  xserver-xorg-input-mtrack : Conflicts: xserver-xorg-input-multitouch but 1.0~rc3-2 is to be installed
#  xserver-xorg-video-nvidia-390 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-418-server : Conflicts: nvidia-driver-binary
#                                         Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-450-server : Conflicts: nvidia-driver-binary
#                                         Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-470 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-470-server : Conflicts: nvidia-driver-binary
#                                         Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-515 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-520 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-525 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-535 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-535-server : Conflicts: nvidia-driver-binary
#                                         Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-545 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-550 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-550-server : Conflicts: nvidia-driver-binary
#                                         Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-555 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-560 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-565 : Conflicts: nvidia-driver-binary
#                                  Conflicts: xorg-driver-binary
#  xserver-xorg-video-nvidia-565-server : Conflicts: nvidia-driver-binary
#                                         Conflicts: xorg-driver-binary
#  yagiuda : Conflicts: psi3 but 3.4.0-6ubuntu1 is to be installed
#  yaskkserv : Conflicts: skkserv
#  zabbix-proxy-mysql : Conflicts: zabbix-proxy-pgsql but 1:5.0.17+dfsg-1 is to be installed
#                       Conflicts: zabbix-proxy-sqlite3 but 1:5.0.17+dfsg-1 is to be installed
#                       Conflicts: zabbix-server-mysql but 1:5.0.17+dfsg-1 is to be installed
#                       Conflicts: zabbix-server-pgsql but 1:5.0.17+dfsg-1 is to be installed
#  zabbix-proxy-pgsql : Conflicts: zabbix-proxy-mysql but 1:5.0.17+dfsg-1 is to be installed
#                       Conflicts: zabbix-proxy-sqlite3 but 1:5.0.17+dfsg-1 is to be installed
#                       Conflicts: zabbix-server-mysql but 1:5.0.17+dfsg-1 is to be installed
#                       Conflicts: zabbix-server-pgsql but 1:5.0.17+dfsg-1 is to be installed
#  zabbix-proxy-sqlite3 : Conflicts: zabbix-proxy-mysql but 1:5.0.17+dfsg-1 is to be installed
#                         Conflicts: zabbix-proxy-pgsql but 1:5.0.17+dfsg-1 is to be installed
#                         Conflicts: zabbix-server-mysql but 1:5.0.17+dfsg-1 is to be installed
#                         Conflicts: zabbix-server-pgsql but 1:5.0.17+dfsg-1 is to be installed
#  zabbix-server-mysql : Conflicts: zabbix-proxy-mysql but 1:5.0.17+dfsg-1 is to be installed
#                        Conflicts: zabbix-proxy-pgsql but 1:5.0.17+dfsg-1 is to be installed
#                        Conflicts: zabbix-proxy-sqlite3 but 1:5.0.17+dfsg-1 is to be installed
#                        Conflicts: zabbix-server-pgsql but 1:5.0.17+dfsg-1 is to be installed
#  zabbix-server-pgsql : Conflicts: zabbix-proxy-mysql but 1:5.0.17+dfsg-1 is to be installed
#                        Conflicts: zabbix-proxy-pgsql but 1:5.0.17+dfsg-1 is to be installed
#                        Conflicts: zabbix-proxy-sqlite3 but 1:5.0.17+dfsg-1 is to be installed
#                        Conflicts: zabbix-server-mysql but 1:5.0.17+dfsg-1 is to be installed
#  zeek-aux : Conflicts: bro-aux but 0.42-1 is to be installed
#  zephyr-server : Conflicts: zephyr-server-krb5 but 3.1.2-1build3 is to be installed
#  zephyr-server-krb5 : Conflicts: zephyr-server
#  zfs-test : Conflicts: zutils but 1.11-1 is to be installed
#  zfsutils-linux : Conflicts: zfs-fuse but 0.7.0-22ubuntu1 is to be installed
#  zoo-kernel : Depends: libotbapplicationengine-8.0-1 (>= 7.0.0) but it is not installable
#               Depends: libotbcommon-8.0-1 (>= 5.2.0) but it is not installable
# E: Unable to correct problems, you have held broken packages.
# tar: ...: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (0.10.9.7)

# %%
import os
# Find the latest version of spark 3.x  from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.4.0'
spark_version = 'spark-3.5.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# Import packages
from pyspark.sql import SparkSession
import time

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQL").getOrCreate()

# %%
# 1. Read in the AWS S3 bucket into a DataFrame.
from pyspark import SparkFiles
url = "https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.2/22-big-data/home_sales_revised.csv"
spark.sparkContext.addFile(url)
df = spark.read.csv(SparkFiles.get("home_sales_revised.csv"), sep=",", header=True)
df.show()
# Out:
# +--------------------+----------+----------+------+--------+---------+-----------+--------+------+----------+----+
# |                  id|      date|date_built| price|bedrooms|bathrooms|sqft_living|sqft_lot|floors|waterfront|view|
# +--------------------+----------+----------+------+--------+---------+-----------+--------+------+----------+----+
# |f8a53099-ba1c-47d...|2022-04-08|      2016|936923|       4|        3|       3167|   11733|     2|         1|  76|
# |7530a2d8-1ae3-451...|2021-06-13|      2013|379628|       2|        2|       2235|   14384|     1|         0|  23|
# |43de979c-0bf0-4c9...|2019-04-12|      2014|417866|       2|        2|       2127|   10575|     2|         0|   0|
# |b672c137-b88c-48b...|2019-10-16|      2016|239895|       2|        2|       1631|   11149|     2|         0|   0|
# |e0726d4d-d595-407...|2022-01-08|      2017|424418|       3|        2|       2249|   13878|     2|         0|   4|
# |5aa00529-0533-46b...|2019-01-30|      2017|218712|       2|        3|       1965|   14375|     2|         0|   7|
# |131492a1-72e2-4a8...|2020-02-08|      2017|419199|       2|        3|       2062|    8876|     2|         0|   6|
# |8d54a71b-c520-44e...|2019-07-21|      2010|323956|       2|        3|       1506|   11816|     1|         0|  25|
# |e81aacfe-17fe-46b...|2020-06-16|      2016|181925|       3|        3|       2137|   11709|     2|         0|  22|
# |2ed8d509-7372-46d...|2021-08-06|      2015|258710|       3|        3|       1918|    9666|     1|         0|  25|
# |f876d86f-3c9f-42b...|2019-02-27|      2011|167864|       3|        3|       2471|   13924|     2|         0|  15|
# |0a2bd445-8508-4d8...|2021-12-30|      2014|337527|       2|        3|       1926|   12556|     1|         0|  23|
# |941bad30-eb49-4a7...|2020-05-09|      2015|229896|       3|        3|       2197|    8641|     1|         0|   3|
# |dd61eb34-6589-4c0...|2021-07-25|      2016|210247|       3|        2|       1672|   11986|     2|         0|  28|
# |f1e4cef7-d151-439...|2019-02-01|      2011|398667|       2|        3|       2331|   11356|     1|         0|   7|
# |ea620c7b-c2f7-4c6...|2021-05-31|      2011|437958|       3|        3|       2356|   11052|     1|         0|  26|
# |f233cb41-6f33-4b0...|2021-07-18|      2016|437375|       4|        3|       1704|   11721|     2|         0|  34|
# |c797ca12-52cd-4b1...|2019-06-08|      2015|288650|       2|        3|       2100|   10419|     2|         0|   7|
# |0cfe57f3-28c2-472...|2019-10-04|      2015|308313|       3|        3|       1960|    9453|     2|         0|   2|
# |4566cd2a-ac6e-435...|2019-07-15|      2016|177541|       3|        3|       2130|   10517|     2|         0|  25|
# +--------------------+----------+----------+------+--------+---------+-----------+--------+------+----------+----+
# only showing top 20 rows

# %%
# 2. Create a temporary view of the DataFrame.
df.createOrReplaceTempView('home_sales')

# %%
# 3. What is the average price for a four bedroom house sold per year, rounded to two decimal places?
sqlQuery ="""
SELECT YEAR(date) AS YEAR, ROUND(AVG(price),2) AS AVERAGE_PRICE
FROM home_sales
WHERE bedrooms = 4
GROUP BY YEAR
ORDER BY YEAR DESC
"""
spark.sql(sqlQuery).show()
# Out:
# +----+-------------+
# |YEAR|AVERAGE_PRICE|
# +----+-------------+
# |2022|    296363.88|
# |2021|    301819.44|
# |2020|    298353.78|
# |2019|     300263.7|
# +----+-------------+

# %%
# 4. What is the average price of a home for each year the home was built,
# that have 3 bedrooms and 3 bathrooms, rounded to two decimal places?
sqlQuery ="""
SELECT YEAR(date_built) AS YEAR, ROUND(AVG(price),2) AS AVERAGE_PRICE
FROM home_sales
WHERE bedrooms = 3 AND bathrooms = 3
GROUP BY YEAR(date_built)
ORDER BY YEAR DESC
"""
spark.sql(sqlQuery).show()
# Out:
# +----+-------------+
# |YEAR|AVERAGE_PRICE|
# +----+-------------+
# |2017|    292676.79|
# |2016|    290555.07|
# |2015|     288770.3|
# |2014|    290852.27|
# |2013|    295962.27|
# |2012|    293683.19|
# |2011|    291117.47|
# |2010|    292859.62|
# +----+-------------+

# %%
# 5. What is the average price of a home for each year the home was built,
# that have 3 bedrooms, 3 bathrooms, with two floors,
# and are greater than or equal to 2,000 square feet, rounded to two decimal places?
sqlQuery ="""
SELECT YEAR(date_built) AS YEAR, ROUND(AVG(price),2) AS AVERAGE_PRICE
FROM home_sales
WHERE bedrooms = 3 AND bathrooms = 3 AND floors = 2 AND sqft_living >= 2000
GROUP BY YEAR(date_built)
ORDER BY YEAR DESC
"""
spark.sql(sqlQuery).show()
# Out:
# +----+-------------+
# |YEAR|AVERAGE_PRICE|
# +----+-------------+
# |2017|    280317.58|
# |2016|     293965.1|
# |2015|    297609.97|
# |2014|    298264.72|
# |2013|    303676.79|
# |2012|    307539.97|
# |2011|    276553.81|
# |2010|    285010.22|
# +----+-------------+

# %%
# 6. What is the average price of a home per "view" rating, rounded to two decimal places,
# having an average home price greater than or equal to $350,000? Order by descending view rating.
# Although this is a small dataset, determine the run time for this query.

start_time = time.time()
sqlQuery = """
SELECT view, ROUND(AVG(price),2) AS AVERAGE_PRICE
FROM home_sales
GROUP BY view
HAVING AVG(price) >= 350000
ORDER BY view DESC
"""
spark.sql(sqlQuery).show()


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+-------------+
# |view|AVERAGE_PRICE|
# +----+-------------+
# |  99|   1061201.42|
# |  98|   1053739.33|
# |  97|   1129040.15|
# |  96|   1017815.92|
# |  95|    1054325.6|
# |  94|    1033536.2|
# |  93|   1026006.06|
# |  92|    970402.55|
# |  91|   1137372.73|
# |  90|   1062654.16|
# |  89|   1107839.15|
# |  88|   1031719.35|
# |  87|    1072285.2|
# |  86|   1070444.25|
# |  85|   1056336.74|
# |  84|   1117233.13|
# |  83|   1033965.93|
# |  82|    1063498.0|
# |  81|   1053472.79|
# |  80|    991767.38|
# +----+-------------+
# only showing top 20 rows
#
# --- 2.0002501010894775 seconds ---

# %%
# 7. Cache the the temporary table home_sales.
spark.sql('cache table home_sales')
# Out:
# DataFrame[]

# %%
# 8. Check if the table is cached.
spark.catalog.isCached('home_sales')
# Out:
# True

# %%
# 9. Using the cached data, run the last query above, that calculates
# the average price of a home per "view" rating, rounded to two decimal places,
# having an average home price greater than or equal to $350,000.
# Determine the runtime and compare it to the uncached runtime.

start_time = time.time()
sqlQuery = """
SELECT view, ROUND(AVG(price),2) AS AVERAGE_PRICE
FROM home_sales
GROUP BY view
HAVING AVG(price) >= 350000
ORDER BY view DESC
"""
spark.sql(sqlQuery).show()


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+-------------+
# |view|AVERAGE_PRICE|
# +----+-------------+
# |  99|   1061201.42|
# |  98|   1053739.33|
# |  97|   1129040.15|
# |  96|   1017815.92|
# |  95|    1054325.6|
# |  94|    1033536.2|
# |  93|   1026006.06|
# |  92|    970402.55|
# |  91|   1137372.73|
# |  90|   1062654.16|
# |  89|   1107839.15|
# |  88|   1031719.35|
# |  87|    1072285.2|
# |  86|   1070444.25|
# |  85|   1056336.74|
# |  84|   1117233.13|
# |  83|   1033965.93|
# |  82|    1063498.0|
# |  81|   1053472.79|
# |  80|    991767.38|
# +----+-------------+
# only showing top 20 rows
#
# --- 0.6541931629180908 seconds ---

# %%
# 10. Partition by the "date_built" field on the formatted parquet home sales data
df.write.partitionBy('date_built').parquet('p_home_sales',mode='overwrite')

# %%
# 11. Read the parquet formatted data.
p_df = spark.read.parquet('p_home_sales')

# %%
# 12. Create a temporary table for the parquet data.
p_df.createOrReplaceTempView('p_home_sales')

# %%
# 13. Using the parquet DataFrame, run the last query above, that calculates
# the average price of a home per "view" rating, rounded to two decimal places,
# having an average home price greater than or equal to $350,000.
# Determine the runtime and compare it to the cached runtime.

start_time = time.time()
sqlQuery = """
SELECT view, ROUND(AVG(price),2) AS AVERAGE_PRICE
FROM home_sales
GROUP BY view
HAVING AVG(price) >= 350000
ORDER BY view DESC
"""
spark.sql(sqlQuery).show()


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+-------------+
# |view|AVERAGE_PRICE|
# +----+-------------+
# |  99|   1061201.42|
# |  98|   1053739.33|
# |  97|   1129040.15|
# |  96|   1017815.92|
# |  95|    1054325.6|
# |  94|    1033536.2|
# |  93|   1026006.06|
# |  92|    970402.55|
# |  91|   1137372.73|
# |  90|   1062654.16|
# |  89|   1107839.15|
# |  88|   1031719.35|
# |  87|    1072285.2|
# |  86|   1070444.25|
# |  85|   1056336.74|
# |  84|   1117233.13|
# |  83|   1033965.93|
# |  82|    1063498.0|
# |  81|   1053472.79|
# |  80|    991767.38|
# +----+-------------+
# only showing top 20 rows
#
# --- 0.48111653327941895 seconds ---

# %%
# 14. Uncache the home_sales temporary table.
spark.sql('uncache table home_sales')
# Out:
# DataFrame[]

# %%
# 15. Check if the home_sales is no longer cached
if spark.catalog.isCached('home_sales'):
  print('home_sales is cached')
else:
  print('not cached')
# Out:
# not cached
